# %%
# %matplotlib nbagg
import hyperspy.api as hs
import numpy as np

s = hs.load("cltest.tiff",force_read_resolution=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/external/tifffile/tifffile.py:1834: UserWarning: ome-xml: index out of range
#   warnings.warn("ome-xml: index out of range")
# /usr/local/lib/python3.5/dist-packages/skimage/external/tifffile/tifffile.py:1547: UserWarning: ome-tiff: could not broadcast input array from shape (825066) into shape (0)
#   warnings.warn("ome-tiff: %s" % e)
# /usr/local/lib/python3.5/dist-packages/hyperspy/io.py:341: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   if np.issubdtype(dtype, complex):

# %%
s.plot()
# Out:
# /usr/local/lib/python3.5/dist-packages/hyperspy/io.py:341: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   if np.issubdtype(dtype, complex):
# /usr/local/lib/python3.5/dist-packages/hyperspy/signal.py:1990: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   if np.issubdtype(navigator().dtype, complex):
# <img src="data:image/png;base64,..." width="639.8449065713054">
# <img src="data:image/png;base64,..." width="199.95153330353293">

# %%
print(s.metadata)
print(s.original_metadata)
print(s)
# Out:
#   File "<ipython-input-16-84c3c02d9d36>", line 3
#     print(s)
#         ^
# SyntaxError: invalid syntax

# %%
s.axes_manager
# Out:
# <Axes manager, axes: (463|3, 594)>
#             Name |   size |  index |  offset |   scale |  units
# ================ | ====== | ====== | ======= | ======= | ======
#           height |    463 |      0 |       0 |       1 | <undefined>
# ---------------- | ------ | ------ | ------- | ------- | ------
# color|em-wavelen |      3 |        |       0 |       1 | <undefined>
#            width |    594 |        |       0 |       1 | <undefined>
